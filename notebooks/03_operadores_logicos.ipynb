# %%
cantidad = 20

# %%
# es mayor
cantidad > 0
# Out:
# True

# %%
# es menor
cantidad < 3
# Out:
# False

# %%
# es mayor o igual
cantidad >= 20
# Out:
# True

# %%
# es menor o oigual
cantidad <= 10
# Out:
# False

# %%
ciudad_1 = 'Arequipa'
ciudad_2 = 'Lima'

# es igual
ciudad_1 == ciudad_2
# Out:
# False

# %%
ciudad_1 == 'Arequipa'
# Out:
# True

# %%
ciudad_2 != 'Arequipa'
# Out:
# True

# %%
cantidad = 20
precio = 10

cantidad > 5 and precio > 10
# Out:
# False

# %%
cantidad > 5 or precio > 10
# Out:
# True

# %%
es_valido = False
not es_valido
# Out:
# True

# %%
es_valido = True
not es_valido
# Out:
# False

# %%
# es nulo
identificador = None

identificador is None
# Out:
# True
