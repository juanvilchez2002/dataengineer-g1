# %% [markdown]
# ### Tuplas

# %%
punto = ("Arequipa", 12.455, -77.123)
type(punto)
# Out:
# tuple

# %%
punto[1]=99.99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 punto[1]=99.99
#
# TypeError: 'tuple' object does not support item assignment

# %%
## tupla vacia
vacia = ()
type(vacia)
# Out:
# tuple

# %%
# tupla de un elemento
tupla_1 = (4,)
type(tupla_1)
# Out:
# tuple
