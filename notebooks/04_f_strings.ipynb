# %%
mi_nombre = 'Juan'

print("me llamo:", mi_nombre)
# Out:
# me llamo: Juan

# %%
print(f"me llamo: {mi_nombre}")
# Out:
# me llamo: Juan

# %%
cliente = "Juan Vilchez"
total = 6000.555555

print("Cliente:", cliente,"|", "Total:", total)
# Out:
# Cliente: Juan Vilchez | Total: 6000.555555

# %%
print(f"Cliente: {cliente} | Total: {total}")
print(f"Cliente: {cliente} | Total: {total * 2}")
print(f"Cliente: {cliente} | Total: {total:.2f}")
# Out:
# Cliente: Juan Vilchez | Total: 6000.555555
# Cliente: Juan Vilchez | Total: 12001.11111
# Cliente: Juan Vilchez | Total: 6000.56
