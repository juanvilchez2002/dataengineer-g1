# %%
regiones = ['Lima', 'Cuzco', 'Piura', 'Loreto']
vacia = []
mixta = ['V-1001', 2, 23.45, True]

# %%
regiones[0]
# Out:
# 'Lima'

# %%
regiones[-1]
# Out:
# 'Loreto'

# %%
len(regiones)
# Out:
# 4

# %%
"Cuzco" in regiones
# Out:
# True

# %%
regiones.index('Piura')
# Out:
# 2

# %%
ventas = [32, 1450, 890.5]
len(ventas)
# Out:
# 3

# %%
ventas.append(2100)
ventas
# Out:
# [32, 1450, 890.5, 2100]

# %%
ventas.append(5000)
ventas
# Out:
# [32, 1450, 890.5, 2100, 5000]

# %%
ventas.append([1,3])
ventas
# Out:
# [32, 1450, 890.5, 2100, 5000, [1, 3]]

# %%
# adiciono una lista a mi lista inicial
ventas.extend([4,5])
ventas
# Out:
# [32, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
# insertar en una posición indicada (posición, elemento)
ventas.insert(0, 55)
ventas
# Out:
# [55, 32, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.insert(2, 99)
ventas
# Out:
# [55, 32, 99, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
# eliminar un elemento determinado
ventas.remove(55)
ventas
# Out:
# [32, 99, 1450, 890.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.remove([1,3])
ventas
# Out:
# [32, 99, 1450, 890.5, 2100, 5000, 4, 5]

# %% [markdown]
# ### Ordenar

# %%
ventas
# Out:
# [32, 99, 1450, 890.5, 2100, 5000, 4, 5]

# %%
# ordenar en la misma lista
ventas.sort()
ventas
# Out:
# [4, 5, 32, 99, 890.5, 1450, 2100, 5000]

# %%
# ordenar la lista de forma inversa
ventas.sort(reverse=True)
ventas
# Out:
# [5000, 2100, 1450, 890.5, 99, 32, 5, 4]

# %%
# sorted ordena una lista pero no la almacena en la lista original
ventas_asc = sorted(ventas)
ventas_asc
# Out:
# [4, 5, 32, 99, 890.5, 1450, 2100, 5000]

# %%
ventas
# Out:
# [5000, 2100, 1450, 890.5, 99, 32, 5, 4]

# %% [markdown]
# ### Operaciones / Agregaciones

# %%
ventas = [1,2,3,4,5,5,6,7,8,2]
sum(ventas)
# Out:
# 43

# %%
min(ventas)
# Out:
# 1

# %%
max(ventas)
# Out:
# 5

# %%
len(ventas)
# Out:
# 10

# %%
ventas.count(5)
# Out:
# 2
