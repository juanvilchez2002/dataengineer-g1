# %%
regiones = ['Lima', 'Cuzco', 'Piura', 'Loreto']
vacia = []
mixta = ['V-1001', 2, 23.45, True]

# %%
regiones[0]
# Out:
# 'Lima'

# %%
regiones[-1]
# Out:
# 'Loreto'

# %%
len(regiones)
# Out:
# 4

# %%
"Cuzco" in regiones
# Out:
# True

# %%
regiones.index('Piura')
# Out:
# 2

# %%
ventas = [32, 1450, 890.5]
len(ventas)
# Out:
# 3

# %%
ventas.append(2100)
ventas
# Out:
# [32, 1450, 890.5, 2100, 2100]

# %%
ventas.append(5000)
ventas
# Out:
# [32, 1450, 890.5, 2100, 2100, 5000]

# %%
ventas.append([1,3])
ventas
# Out:
# [32, 1450, 890.5, 2100, 2100, 5000, [1, 3]]

# %%
# adiciono una lista a mi lista inicial
ventas.extend([4,5])
ventas
# Out:
# [32, 1450, 890.5, 2100, 2100, 5000, [1, 3], 4, 5]

# %%
# insertar en una posición indicada (posición, elemento)
ventas.insert(0, 55)
ventas
# Out:
# [55, 32, 1450, 890.5, 2100, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.insert(2, 99)
ventas
# Out:
# [55, 32, 99, 1450, 890.5, 2100, 2100, 5000, [1, 3], 4, 5]

# %%
# eliminar un elemento determinado
ventas.remove(55)
ventas
# Out:
# [32, 99, 1450, 890.5, 2100, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.remove([1,3])
ventas
# Out:
# [32, 99, 1450, 890.5, 2100, 2100, 5000, 4, 5]
